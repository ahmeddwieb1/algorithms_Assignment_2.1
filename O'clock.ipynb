# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmeddwieb1/algorithms_Assignment_2.1/blob/master/O'clock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def increment(number):
    if number == 3:
        return 0
    else:
        return number + 1

# %%
increment(2)
# Out:
# 3

# %%
letters = ["A", "B", "C", "D", "E", "F", "G", "H", "I"]

with open("input.txt") as f:
    nums = list(map(int, f.read().split()))


values = {letters[i]: nums[i] for i in range(9)}
print (values)
# Out:
# {'A': 3, 'B': 3, 'C': 0, 'D': 2, 'E': 2, 'F': 2, 'G': 2, 'H': 1, 'I': 2}

# %%
def values_to_tuple(values):
    return tuple(values[l] for l in letters)

# %%
def actions(values):
    actions_list   = []
    for i in values:
        if values[i] != 0:
          actions_list.append(i)
    return actions_list
#test
print(actions(values))
# Out:
# ['A', 'B', 'D', 'E', 'F', 'G', 'H', 'I']

# %%
moves = {
    1: ["A","B","D","E"],
    2: ["A","B","C"],
    3: ["B","C","E","F"],
    4: ["A","D","G"],
    5: ["B","D","E","F","H"],
    6: ["C","F","I"],
    7: ["D","E","G","H"],
    8: ["G","H","I"],
    9: ["E","F","H","I"],
}

# %%
# for i in moves:
#   print (moves[i])

# %%
# compare between action and moves [2]
# action = actions(values)
# if all(x in action for x in moves[9]):
#     print("accept")
# else:
#     print("reject")

# %%
# action = actions(values)
# for i in moves:
#   if all(x in action for x in moves[i]):
#     print(i)

# %%
# test
# for i in values:
#         values[i]=0
# print(values)

# %%
def winner(values):
    for i in values:
            if values[i] != 0:
                return 0
    return 1
# print (winner(initial_state()))

# %%
def terminal (board ,moves):
  vaid_move = []
  action = actions(values)
  for i in moves:
    if all(x in action for x in moves[i]):
      vaid_move.append(i)
  return vaid_move
print (terminal(values,moves))
# Out:
# [1, 4, 5, 7, 8, 9]

# %%
# def add (board,moves):
#   for i in moves[1]:
#     values[i]=increment(values[i])
  # print(i)
  # print(values)

# %%
def add(values, move_number):
    new_values = values.copy()
    for letter in moves[move_number]:
        new_values[letter] = increment(new_values[letter])
    return new_values

# %% [markdown]
# # monstar level
